# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Data.zip" -d "/content/drive/MyDrive/data"
# Out:
# Archive:  /content/drive/MyDrive/Data.zip
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103157.jpg
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103157.txt
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103200.jpg
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103200.txt
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103209.jpg
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103209.txt
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103219.jpg
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103219.txt
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103224.jpg
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103224.txt
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103241.jpg
#   inflating: /content/drive/MyDrive/data/images/IMG_20220731_103241.txt
# ...

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/darknet
# Out:
# /content/drive/MyDrive/darknet

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15460, done.
# remote: Total 15460 (delta 0), reused 0 (delta 0), pack-reused 15460
# Receiving objects: 100% (15460/15460), 14.07 MiB | 6.41 MiB/s, done.
# Resolving deltas: 100% (10385/10385), done.
# Checking out files: 100% (2053/2053), done.

# %%
# %cd /content/drive/MyDrive/darknet
# !make
# Out:
# /content/drive/MyDrive/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
dat = '/content/drive/MyDrive/darknet/train_test_files/obj.data'
cfg = '/content/drive/MyDrive/darknet/cfg/yolov3.cfg'
wgt = '/content/drive/MyDrive/pretrained_model/darknet53.conv.74'
# !darknet/darknet detector train {dat} {cfg} {wgt} -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 58934, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.876737), count: 4, class_loss = 0.138163, iou_loss = 0.150226, total_loss = 0.288390
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...

# %%
"/content/drive/MyDrive/darknet/train_test_files/classes.names"

# %%
# !chmod +x darknet/darknet

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive
# !mkdir pretrained_model
# %cd /content/drive/MyDrive/pretrained_model
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive/pretrained_model
# --2022-07-31 11:56:32--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  20.1MB/s    in 8.7s
#
# 2022-07-31 11:56:42 (17.9 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# #Testing Images

# %%
img_path = input('Enter Image Path: ')
dat = '/content/drive/MyDrive/darknet/train_test_files/obj.data'
cfg = '/content/drive/MyDrive/darknet/cfg/yolov3.cfg'
wgt = '/content/drive/MyDrive/backup/yolov3_best.weights'
# !darknet/darknet detector test {dat} {cfg} {egt} {img_path} -dont-show -map
# Out:
# Enter Image Path: /content/drive/MyDrive/images/mask.jpg
# CUDA status Error: file: ./src/dark_cuda.c : () : line: 38 : build time: Jul 31 2022 - 07:46:53
#
#  CUDA Error: no CUDA-capable device is detected
# Darknet error location: ./src/dark_cuda.c, check_error, line #69
# CUDA Error: no CUDA-capable device is detected: Bad file descriptor
